# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data1 = pd.read_csv('weatherHistory.csv')
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
# Formatted_Date              96453 non-null object
# Summary                     96453 non-null object
# Precip_Type                 95936 non-null object
# Temperature_(C)             96453 non-null float64
# Apparent_Temperature_(C)    96453 non-null float64
# Humidity                    96453 non-null float64
# Wind_Speed_(km/h)           96453 non-null float64
# Wind_Bearing_(degrees)      96453 non-null float64
# Visibility_(km)             96453 non-null float64
# Loud_Cover                  96453 non-null float64
# Pressure_(millibars)        96453 non-null float64
# Daily_Summary               96453 non-null object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
data1.hist(bins=50, figsize=(8,6))
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(data1, test_size=0.2, random_state=35)

print("data has {} instances\n {} train instances\n {} test intances".
      format(len(data1),len(train_set),len(test_set)))
# Out:
# data has 96453 instances
#  77162 train instances
#  19291 test intances

# %%
train = train_set.copy()

# %%
corr_matrix = train.corr()
corr_matrix["Temperature_(C)"].\
  sort_values(ascending=False)
# Out:
# Temperature_(C)             1.000000
# Apparent_Temperature_(C)    0.992612
# Wind_Bearing_(degrees)      0.028813
# Wind_Speed_(km/h)           0.000806
# Pressure_(millibars)       -0.004093
# Visibility_(km)            -0.094965
# Humidity                   -0.632908
# Loud_Cover                       NaN
# Name: Temperature_(C), dtype: float64

# %%
import seaborn as sns
sns.heatmap(train.corr(), 
            annot=True, fmt=".2f")

# %%
# A retirada das colunas "Formatted_Date", "Precip_Type", "Daily_Summary" foi feita com o intuito de
# simplificar e diminuição do numero de colunas que será necessário o uso do one-hot encoding, diminuido o tempo
# de execução das celulas
train_X = train_set.drop(["Temperature_(C)", "Formatted_Date", "Precip_Type", "Daily_Summary"], axis=1)

train_y = train_set["Temperature_(C)"].copy()

# %%
train_X.isnull().sum()
# Out:
# Summary                     0
# Apparent_Temperature_(C)    0
# Humidity                    0
# Wind_Speed_(km/h)           0
# Wind_Bearing_(degrees)      0
# Visibility_(km)             0
# Loud_Cover                  0
# Pressure_(millibars)        0
# dtype: int64

# %%
print('Média das temperaturas: ', train_set["Temperature_(C)"].mean())
print('Desvio Padrão das temperaturas: ', train_set["Temperature_(C)"].std())
# Out:
# Média das temperaturas:  11.955920300435796
# Desvio Padrão das temperaturas:  9.557334099929118

# %%
train_X.Summary.value_counts()
# Out:
# Partly Cloudy               25342
# Mostly Cloudy               22435
# Overcast                    13286
# Clear                        8760
# Foggy                        5725
# Breezy and Overcast           418
# Breezy and Mostly Cloudy      416
# Breezy and Partly Cloudy      306
# Dry and Partly Cloudy          71
# Windy and Partly Cloudy        57
# Light Rain                     51
# Breezy                         46
# Humid and Mostly Cloudy        37
# Windy and Overcast             37
# Drizzle                        34
# Windy and Mostly Cloudy        31
# Breezy and Foggy               29
# Dry                            28
# Humid and Partly Cloudy        15
# Dry and Mostly Cloudy          12
# Windy                           7
# Rain                            7
# Humid and Overcast              7
# Windy and Foggy                 3
# Windy and Dry                   1
# Breezy and Dry                  1
# Name: Summary, dtype: int64

# %%
train_X_cat_encoded, train_X_categories = train_X.Summary.factorize()

print(train_X_cat_encoded[0:20])
print(train_X_categories)
# Out:
# [0 0 1 0 1 2 3 0 3 1 3 0 3 4 4 0 1 1 3 0]
# Index(['Mostly Cloudy', 'Overcast', 'Foggy', 'Clear', 'Partly Cloudy',
#        'Windy and Partly Cloudy', 'Breezy and Partly Cloudy',
#        'Breezy and Overcast', 'Breezy', 'Breezy and Mostly Cloudy',
#        'Dry and Partly Cloudy', 'Humid and Overcast', 'Windy and Overcast',
#        'Windy and Mostly Cloudy', 'Humid and Partly Cloudy', 'Light Rain',
#        'Drizzle', 'Windy and Foggy', 'Rain', 'Breezy and Foggy',
#        'Humid and Mostly Cloudy', 'Dry and Mostly Cloudy', 'Dry', 'Windy',
#        'Windy and Dry', 'Breezy and Dry'],
#       dtype='object')

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder 
from sklearn.base import BaseEstimator, TransformerMixin

class Encoder(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names
        
        train_X_cat_encoded, train_X_categories = self.attribute_names.factorize()
        
        encoder = OneHotEncoder()

        train_X_cat_1hot = encoder.fit_transform(train_X_cat_encoded.reshape(-1,1))
        return train_X_cat_1hot

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.base import BaseEstimator, TransformerMixin

class DataFrameSelector(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        return X[self.attribute_names].values

# %%
from sklearn.pipeline import FeatureUnion


train_X_num = train_X.drop("Summary", axis=1)

num_list = list(train_X_num)

num_pipeline = Pipeline([('selector', DataFrameSelector(num_list)),
                         ('std_scaler', StandardScaler())
                        ])

cat_attribs = "Summary"

cat_pipeline = Pipeline([('selector', DataFrameSelector(cat_attribs)),
                         ('cat_encoder', Encoder(cat_attribs))
                        ])



test_pipeline = FeatureUnion(transformer_list=[("num_pipeline", num_pipeline),
                                               ("cat_pipeline", cat_pipeline)
                                              ])

train_X_pipeline = test_pipeline.fit_transform(train_X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-dd63c5a9037c> in <module>()
#      13
#      14 cat_pipeline = Pipeline([('selector', DataFrameSelector(cat_attribs)),
# ---> 15                          ('cat_encoder', Encoder(cat_attribs))
#      16                         ])
#      17
#
# <ipython-input-46-8410b2f84392> in __init__(self, attribute_names)
#       7         self.attribute_names = attribute_names
#       8
# ----> 9         train_X_cat_encoded, train_X_categories = self.factorize()
#      10
#      11         encoder = OneHotEncoder()
#
# AttributeError: 'Encoder' object has no attribute 'factorize'

# %%
from sklearn.linear_model import LinearRegression

# create a LinearRegression model
lin_reg = LinearRegression()

# fit it
lin_reg.fit(train_X_pipeline, train_y)

# %%
train_X_pipeline.shape

# %%
print("Predictions:", lin_reg.predict(train_X_pipeline))

# %%
from sklearn.metrics import mean_squared_error

temp_predictions = lin_reg.predict(train_X_pipeline)
lin_mse = mean_squared_error(train_y, temp_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
